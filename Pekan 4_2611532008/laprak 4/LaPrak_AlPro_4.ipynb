# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma Dan Pemograman**
#
# **"Struktur Percabangan pada Python”**
#
# **Disusun Oleh :**
#
# **Muhammad Rafi Firdaus**
#
# **2611532008**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Rifki Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Pemrograman Python dengan judul "Struktur Percabangan pada Python" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python, khususnya pada penerapan fungsi masukan/keluaran dan struktur kontrol kondisi (if-else).
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, 2026
#
# Muhammad Rafi Firdaus

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Seiring dengan perkembangan teknologi informasi yang pesat, penggunaan sistem terkomputerisasi dalam kegiatan transaksi jual beli telah menjadi kebutuhan penting di berbagai sektor usaha. Proses transaksi secara manual sering kali memakan waktu lebih lama dan memiliki risiko kesalahan perhitungan (human error) yang dapat merugikan pihak penjual maupun pembeli. Oleh karena itu, penerapan program kasir yang mampu melakukan perhitungan otomatis sangat diperlukan untuk meningkatkan efisiensi dan akurasi pembayaran.
#
# Dalam dunia pemrograman, bahasa Python menjadi salah satu pilihan utama untuk membangun aplikasi sederhana hingga kompleks karena sintaksnya yang mudah dipahami, efisien, dan fleksibel. Salah satu fitur dasar namun krusial dalam pemrograman Python adalah struktur kontrol percabangan (if-else, if-elif-else, multi-if, serta match-case). Fitur ini memungkinkan program untuk mengambil keputusan secara otomatis berdasarkan kondisi tertentu, seperti penentuan kelulusan IPK, verifikasi izin mengemudi, konversi nilai, hingga perhitungan potongan harga (diskon) bertingkat.
#
# Berdasarkan permasalahan dan konsep tersebut, praktikum ini dilaksanakan untuk merancang dan mengimplementasikan struktur percabangan berbasis Python. Program dibuat untuk melatih pemahaman mendalam mengenai logika dasar komputer, pemrosesan variabel masukan (input), serta penerapan logika kondisi dalam menyelesaikan kasus dunia nyata secara cepat dan tepat.
#
# ## 1.2 Tujuan
# 1. Memahami penggunaan fungsi masukan (input) dan keluaran (print) pada Python.
# 2. Menerapkan pengondisian (conditional statement) menggunakan struktur if-else.
# 3. Melakukan operasi aritmatika dasar untuk menghitung nilai diskon dan total pembayaran.
#
# ## 1.3 Manfaat
# 1. Memahami penerapan logika dasar Python, khususnya penggunaan fungsi input-output dan struktur percabangan if-else dalam menyelesaikan masalah.
# 2. Mempercepat proses perhitungan transaksi belanja serta meminimalisir risiko kesalahan hitung (human error) dalam penentuan diskon dan validasi hak akses.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Struktur percabangan (kontrol keputusan) merupakan struktur logika pemrograman yang memungkinkan jalurnya eksekusi instruksi bercabang berdasarkan pengujian suatu kondisi boolean (True atau False). Pada bahasa Python, terdapat beberapa jenis struktur percabangan utama:
# 1. Struktur Percabangan Tunggal (if): Digunakan untuk mengeksekusi suatu blok kode hanya jika kondisi bernilai True. Jika bernilai False, blok kode tersebut diabaikan.
#
# 2.Struktur Percabangan Ganda (if-else): Menyediakan jalur alternatif. Jika kondisi bernilai True, blok if dieksekusi. Jika bernilai False, blok else yang akan dieksekusi.
#
# 3.Struktur Percabangan Majemuk (if-elif-else): Digunakan ketika terdapat lebih dari dua alternatif kondisi. Pengujian dilakukan secara berurutan dari atas ke bawah hingga ditemukan kondisi pertama yang bernilai True.
#
# 4.Struktur Independen (Multi-IF): Terdiri dari beberapa pernyataan if terpisah yang dievaluasi satu per satu secara mandiri. Struktur ini memungkinkan beberapa blok kondisi dieksekusi sekaligus jika kondisinya saling terpenuhi (seperti akumulasi diskon).
#
# 5.Struktur match-case (Pattern Matching): Diperkenalkan pada Python 3.10+, struktur ini mencocokkan nilai variabel dengan beberapa pola (case) secara ringkas, serupa dengan pernyataan switch-case pada bahasa pemrograman lain.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if1_2611532008"

# %%
ipk_2008 = float(input("Input IPK anda =  "))

if ipk_2008 > 2.75:
    print("Anda Lulus Sangat Memuaskan Dengan IPK " + str(ipk_2008))

print("Program selesai")

# %% [markdown]
# **Penjelasan :**
# 1. Program meminta input berupa IPK dari pengguna yang dikonversi ke tipe data `float` (`ipk_2008`).
# 2. Struktur `if` memeriksa apakah IPK lebih dari `2.75`[cite: 3]. Jika ya, program mencetak pesan selamat.
# 3. Pesan `"Program selesai"` selalu dieksekusi di akhir karena berada di luar blok percabangan.

# %% [markdown]
# ### 2.2.2 Program "if2_2611532008"

# %%
ipk_2008 = float(input("Input IPK Anda = "))

if ipk_2008 > 2.75:
    print("Anda Lulus Sangat Memuaskan Dengan IPK " + str(ipk_2008))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")

# %% [markdown]
# **Penjelasan :**
# 1. Program meminta masukan IPK pengguna.
# 2. Kondisi `if` mengecek apakah `ipk_2008 > 2.75`[cite: 4]. Jika `True`, pesan lulus ditampilkan.
# 3. Jika kondisi `False` ($\le 2.75$), blok `else` berjalan dan menampilkan `"Anda Tidak Lulus"

# %% [markdown]
# ### 2.2.3 Program "multi_if1_2611532008"

# %%
umur_2008 = int (input("Input umur anda: "))
sim_2008 = input("Apakah anda sudah punya sim C (y/t): ")[0]

if umur_2008 >= 17 and sim_2008 == 'y':
   print("Anda sudah dewasa dan boleh bawa motor")

if umur_2008 >= 17 and sim_2008 != 'y':
   print("Anda sudah dewasa tetapi tidak boleh bawa motor")

if umur_2008 < 17 and sim_2008 == 'y':
   print("Anda belum cukup umur punya SIM")

if umur_2008 < 17 and sim_2008 != 'y':
   print("Anda belum cukup umur bawa motor")

# %% [markdown]
# **Penjelasan :**
# 1. Menggunakan 4 pernyataan `if` independen tanpa `elif`/`else`.
# 2. Setiap kondisi diperiksa satu per satu secara terpisah dari atas ke bawah

# %% [markdown]
# ### 2.2.4 Program "multi_if2_2611532008"

# %%
# Input dari user
total_belanja_2008 = float(input("Masukkan total belanja (Rp): "))

# Input status member (Mengecek apakah user mengetik 'y' atau 'ya')
input_member_2008 = input("Apakah anda member? (y/t): ").strip().lower()
is_member_2008 = input_member_2008 in ("y", "ya")

# Input Status kode promo (Mengecek apakah user mengetik 'y' atau 'ya')
input_promo_2008 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_2008 = input_promo_2008 in ("y", "ya")

total_diskon_persen_2008 = 0

# Multi-if Terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi syarat sekaligus

if total_belanja_2008 > 1000000:
    total_diskon_persen_2008 += 10  # Diskon belanja BytesWarning

if is_member_2008:
    total_diskon_persen_2008 += 5 # Diskon member

if kode_promo_valid_2008:    
    total_diskon_persen_2008 += 15 # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_2008 = total_belanja_2008 * (total_diskon_persen_2008 / 100)
total_bayar_2008 = total_belanja_2008 - nominal_diskon_2008

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon : {total_diskon_persen_2008} % (Rp {nominal_diskon_2008:,.0f})")
print(f"Total Bayar : Rp {total_bayar_2008:,.0f}")

print(f"Total diskon yang anda dapatkan: {total_diskon_persen_2008}%")

# %% [markdown]
# **Penjelasan :**
# 1. Meminta input total belanja, status member, dan kode promo.
# 2. Memanfaatkan `multi-if` sehingga diskon dapat diakumulasikan (ditumpuk) apabila memenuhi beberapa kriteria sekaligus.
# 3. Menghitung besaran nominal diskon dan total biaya yang harus dibayar

# %% [markdown]
# ### 2.2.5 Program "if_elif_else1_2611532008"

# %%
umur_2008 = int(input("Input umur anda: "))
sim_2008 = input("Apakah anda sudah punya sim C: ")[0]

if umur_2008 >= 17 and sim_2008== 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

elif umur_2008 >= 17 and sim_2008 != 'y':
    print ("Anda sudah dewasa tetapi tidak boleh bawa motor")

elif umur_2008 < 17 and sim_2008 =='y':
    print ("Anda belum cukup umur punya SIM")

else:
    print("Anda belum cukup umur dan tidak boleh bawa motor")
print("Program selesai")

# %% [markdown]
# **Penjelasan :**
# 1. Program meminta input umur (`umur_2008`) dan kepemilikan SIM (`sim_2008`).
# 2. Menggunakan ekspresi logika `and` untuk memeriksa kombinasi kriteria umur dan SIM.
# 3. Percabangan mengevaluasi pilihan kondisi secara bertahap untuk menentukan hak mengendarai sepeda motor.

# %% [markdown]
# ### 2.2.6 Program "nilai_2611532008"

# %%
nilai_2008 = int(input("Inputkan nilai angka= "))

if nilai_2008 >= 81:
    print("A")
elif nilai_2008 >= 70:
    print("B")
elif nilai_2008 >= 60:
    print("C")
elif nilai_2008 >= 50:
    print("D")
else:
    print("E")

# %% [markdown]
# **Penjelasan :**
# 1. Mengganti nilai numerik (`int`) menjadi nilai huruf (A/B/C/D/E).
# 2. Menggunakan tangga percabangan `if-elif-else` berdasarkan batasan rentang nilai

# %% [markdown]
# ### 2.2.6 Program "match_case1_2611532008"

# %%
bulan_2008 = int(input("Masukkan angka bulan (1-12): "))

match bulan_2008:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("May")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")

# %% [markdown]
# **Penjelasan :**
# 1. Meminta masukan angka 1–12.
# 2. Menggunakan fitur `match-case` untuk mencocokkan input angka dengan nama bulan yang sesuai.
# 3. `case _:` digunakan sebagai penanganan kondisi *default* jika input di luar rentang 1–12

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal : Studi Kasus: Sistem Loket Terpadu & Audit Transaksi Ekspedisi Wahana**

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "SISTEM LOKET ALPRO ADVENTURE PARK"

# %%
# Program Sistem loket terpadu & Audit transaksi ekspedisi wahana

# 1 Input data pengunjung
print ("=== SISTEM LOKET ALPRO  ADVENTURE PARK===")
nama_pengunjung_2008 = str (input("Input Nama Anda: "))
umur_pengunjung_2008 = int (input("Input Umur Anda: "))
sim_2008 = input("Apakah Anda Sudah Mempunyai SIM C (y/t): ").strip().lower()




# 2 Pemilihan Wahana
print("\nPilihan Paket Wahana")
print(" 1. Wahana Safari Simba (Rp 50,000)")
print(" 2. Wahana Arung Jeram (Rp 75,000)")
print(" 3. Wahana Motor ATV Ekstrem (Rp 120,000)")
print(" 4. Wahana Roller Coaster Kilat (Rp 100,000)")
print(" 5. Wahana All-Access VIP (Rp 220,000)")

paket_2008 = int(input("Masukkan nomor paket: "))
match paket_2008:
    case 1: 
        nama_wahana_2008 = "Wahana Safari Simba"
        harga_wahana_2008 = 50000
    case 2:
        nama_wahana_2008 = "Wahana Arung Jeram"
        harga_wahana_2008 = 75000
    case 3:
        nama_wahana_2008 = "Wahana Motor ATV Ekstrem"
        harga_wahana_2008 = 120000
    case 4:
        nama_wahana_2008_2008 = "Wahana Roller Coaster Kilat"
        harga_wahana_2008 = 100000
    case 5:
        nama_wahana_2008 = "Wahana All-Access VIP"
        harga_wahana_2008 = 220000
    case _:
        print("Paket wahana tidak valid!")

jumlah_tiket_2008 = int(input("\nMasukkan jumlah tiket: "))
if jumlah_tiket_2008 <= 0:
    print("Kuota tiket tidak valid!")
input_member_2008 =  input("\nApakah Anda Member? (y/t): ").strip().lower()
is_member_2008 = input_member_2008 in ("y", "ya")
input_kode_promo_valid_2008 = input("Apakah Kode Promo Valid? (y/t): ").strip().lower()
kode_promo_valid_2008 = input_kode_promo_valid_2008 in ("y", "ya")

# 3 Validasi izin kendali wahana
print("\n---KELAYAKAN PENGENDARA WAHANA---")

if paket_2008 == 3 and umur_pengunjung_2008 >= 17 and sim_2008 == 'y':
    status_akses_2008 = ("Anda Sudah Dewasa Dan Boleh Mengendarai ATV Sendiri.")
elif paket_2008 == 3 and umur_pengunjung_2008 >= 17 and sim_2008 != 'y':
    status_akses_2008 = ("Anda Sudah Dewasa Tetapi Tidak Boleh Bawa Motor ATV \n(Wajib Didampingi Instruktur)")
elif paket_2008 == 3 and umur_pengunjung_2008 < 17 and sim_2008 == 'y':
    status_akses_2008 = ("Identitas tidak valid: Belum cukup umur memiliki SIM")
elif paket_2008 == 3 and umur_pengunjung_2008 <17 and sim_2008 != 'y':
    status_akses_2008 = ("Anda Belum Cukup Umur Dan Tidak Boleh Membawa ATV")
elif umur_pengunjung_2008 >= 10:
    status_akses_2008 = ("Anda boleh masuk wahana ini")
else:
    status_akses_2008 = ("Umur anda tidak cukup untuk wahana ini")

print (f"Status Akses: {status_akses_2008}")


# 4 Akumulasi Diskon
# Subtotal 
subtotal_2008 = harga_wahana_2008 * jumlah_tiket_2008

total_diskon_persen_2008 = 0

# Diskon Belanja Besar
if float(subtotal_2008) >= 200000 : 
    total_diskon_persen_2008 += 10
# Diskon member
if is_member_2008:
    total_diskon_persen_2008 += 5
# Diskon Voucher Promo
if kode_promo_valid_2008:
    total_diskon_persen_2008 += 15
# Diskon Tambahan Rombongan
if jumlah_tiket_2008 >= 5:
    total_diskon_persen_2008 += 5

# 5. Evaluasi Kelulusan

# Penghitungan total bayar
nominal_diskon_2008 = subtotal_2008 * (total_diskon_persen_2008 / 100)
total_bayar_2008 = subtotal_2008 - nominal_diskon_2008

# Catatan Layanan 
if total_bayar_2008 > 300000:
    catatan_layanan_2008 = ("Selamat! Anda berhak mendapat Souvenir Gratis.")
else:
    catatan_layanan_2008 = ("Terima Kasih Telah Berkunjung.")

# Rincian pembayaran
print("\n---Rincian Pembayaran---")
print(f"Subtotal Belanja : Rp{subtotal_2008: ,.0f}")
print(f"Total Diskon : {total_diskon_persen_2008}% (Rp{nominal_diskon_2008:,.0f})")
print(f"Total Bayar : Rp {total_bayar_2008:,.0f}")
print(f"Catatan Layanan : {catatan_layanan_2008}")
print("\nProgram Selesai")

# %% [markdown]
# **Penjelasan** :
# 1. **Input Identitas**: Mengambil masukan nama, umur, serta kepemilikan SIM dari pengunjung.
# 2. **Pemilihan Paket Wahana (`match-case`)**: Menentukan jenis wahana beserta harga tiket berdasarkan pilihan angka 1–5.
# 3. **Validasi Kelayakan (`if-elif-else`)**: Khusus Wahana Motor ATV Ekstrem (Paket 3), sistem melakukan pengecekan kombinasi umur dan kepemilikan SIM untuk menentukan apakah pengunjung boleh berkendara sendiri, didampingi instruktur, atau dilarang.
# 4. **Akumulasi Diskon (`multi-if`)**: Menghitung diskon yang dapat diakumulasikan berdasarkan subtotal ($\ge \text{Rp200.000}$ mendapat 10%), status member (5%), promo valid (15%), dan pembelian rombongan ($\ge 5$ tiket mendapat 5%).
# 5. **Output Rincian & Bonus**: Menghitung nominal akhir bayar serta memberikan catatan souvenir gratis jika total transaksi melebihi Rp300.000.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa struktur percabangan merupakan komponen kontrol utama dalam pemrograman Python yang memungkinkan pengambilan keputusan secara logis dan otomatis berdasarkan pemenuhan kondisi tertentu.
#
# Dalam konteks pemrograman Python, konsep ini memanfaatkan ekspresi logika, pernyataan `if-elif-else`, `multi-if`, serta `match-case` sehingga aplikasi dapat menangani berbagai skenario input yang dinamis, seperti validasi akses, konversi nilai, hingga akumulasi perhitungan diskon pada sistem kasir atau loket terpadu secara efisien dan akurat.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Control Flow Statements," *Python 3 Documentation*, 2026. [Online]. Tersedia: [https://docs.python.org/3/tutorial/controlflow.html](https://docs.python.org/3/tutorial/controlflow.html)
