# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma Dan Pemograman**
#
# **“Pengenalan Python, VSCode, dan koneksi ke Github”**
#
# **Disusun Oleh :**
#
# **Muhammad Rafi Firdaus**
#
# **2611532008**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifki Yuliandra***
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pengenalan Python, Visual Studio code, dan koneksi ke Github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pembahasan Pengenalan Python, Visual Studio Code dan Koneksi ke Github.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Pengenalan Python, Visual Studio Code dan Koneksi ke Github pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python merupakan bahasa pemograman yang sangat penting bagi Mahasiswa Informatika. Selain python juga diperlukan Aplikasi Development seperti Visual Studio Code (VSCode) dan Github sebagai program pengelolaan dan publishing.
#
# ## 1.2 Tujuan
# 1. Mengenal dasar penggunaan bahasa Python
# 2. Mengenal dan menggunakan Visual Studio Code untuk membuat dan mengelola program
# 3. Membuat dan Menglink akun Github ke Visual Studio Code
#
# ## 1.3 Manfaat
# 1. Mengetahui penggunaan dasar Python
# 2. Memiliki kemampuan untuk menggunakan Visual Studio Code
# 3. Membangun portfolio dengan memiliki akun Github

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Python adalah bahasa pemrograman tingkat tinggi multiguna yang sangat populer karena sintaksnya yang bersih, mudah dibaca, dan mirip seperti bahasa Inggris.
# 2. Visual Studio Code adalah perangkat lunak digunakan untuk menulis, mengedit, dan menjalankan program, kode sumber gratis dan ringan buatan Microsoft yang dapat dijalankan pada sistem operasi Windows, macOS, dan Linux.
# 3. Github adalah platform berbasis cloud dan layanan hosting web untuk menyimpan, mengelola, serta berkolaborasi dalam pengembangan kode pemograman menggunakan sistem kontrol versi.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "NamaKelas_NIM"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print ("Hello world")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print(" / \\ // \\\\ /// \\\\\ ")
print ("Program ini " "Dibuat oleh a\n"
       "Muhammad Rafi Firdaus 2611532008")

# %% [markdown]
# **Penjelasan :**
# 1. Barisan Pertama sampai keenam berfungsi sebagai penjelas program
# 2. Bagian tujuh samapi akhir berfungsi untuk mengprint output
# 3. Dijalankan dengan Bahasa Python

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal : buatlah sebuah file program python bebas dengan nama tugas1_nim.py**

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas1_2611532008.py"

# %%
print("=== BIODATA MAHASISWA ===")
print("Nama    : Muhammad Rafi Firdaus")
print("NIM     : 2611532008")
print("Jurusan : Informatika")
print("Kelas   : IF B")
print("Hobi    : Bermain Game")
print()
print()
print()
print("***************")
print("***************")
print("***************")
print("***************")
print("***************")
print("***************")
print("| | | |")
print("| | | |")
print("| | | |")

# %% [markdown]
# **Output** :
#
# **Penjelasan :**
#
#  Program ini berfungsi untuk menampilkan biodata mahasiswa dan membuat Pola menggunakan simbol * dan |.
#
# Perintah Print pertama sampai keenam berfungsi untuk menampilkan biodata.
#
#
# Perintah Print tujuh sampai sembilan berfungsi untuk memberi jarak.
#
#
# Perintah Print sepuluh sampai sembilan belas berfungsi untuk menampilkan pola.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python adalah bahasa pemograman digunakan untuk membuat program serta menjalankan program. Visual Studio Code digunakan sebagai Program menulis dan menjalankan Kode Python. Dan Github berfungsi untuk menyimpan dan mengelola hasil pengodean.
#
# Dalam Praktikum ini. Saya mempelajari Python, Visual Studio Code, dan Github.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Python Documentation," Python, [Online]. Tersedia: https://docs.python.org/3/.
#
# [2] Microsoft, "Visual Studio Code Documentation," Visual Studio Code, [Online]. Tersedia: https://code.visualstudio.com/docs.
#
# [3] GitHub, "GitHub Documentation," GitHub, [Online]. Tersedia: https://docs.github.com/.
